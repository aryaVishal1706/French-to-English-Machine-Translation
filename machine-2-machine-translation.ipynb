# %% [markdown]
# Basic code for machine translation using Seq2Seq (No Attention Mechanism Used). Can be made more computationally efficient by masking padded tokens. Other possibilities include: Better Initialization, Better Architecture, Better Training.
# 1. Prepare Data
#     1.1 Read data
#     1.2 Create normalized pairs (create + normalize (unicode 2 ascii, remove non-letter characters, trim)) (list of lists, each list will be a pair)
#     1.3 Filter pairs
#     1.4 Build vocab (Write Vocab class, Create Vocab objects for each class, and build vocab)
# 2. Define Encoder and Decoder
# 3. Prepare Data and DataLoader
# 4. Training
# 5. Evaluation

# %%
import torch
import torch.nn as nn
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split

from io import open
import unicodedata
import re

# %%
if torch.cuda.is_available():
    device=torch.device(type='cuda', index=0)
else:
    device=torch.device(type='cpu', index=0)

# %%
#unicode 2 ascii, remove non-letter characters, trim
def normalizeString(s): 
    sres=""
    for ch in unicodedata.normalize('NFD', s): 
        #Return the normal form form ('NFD') for the Unicode string s.
        if unicodedata.category(ch) != 'Mn':
            # The function in the first part returns the general 
            # category assigned to the character ch as string. 
            # "Mn' refers to Mark, Nonspacing
            sres+=ch
    sres = re.sub(r"([.!?])", r" \1", sres) 
    # inserts a space before any occurrence of ".", "!", or "?" in the string sres. 
    sres = re.sub(r"[^a-zA-Z!?]+", r" ", sres) 
    # this line of code replaces any sequence of characters in sres 
    # that are not letters (a-z or A-Z) or the punctuation marks 
    # "!" or "?" with a single space character.
    return sres.strip()

#create list of pairs (list of lists) (no filtering)
def createNormalizedPairs():
    initpairs=[]
    for pair in data:
        s1,s2=pair.split('\t')
        s1=normalizeString(s1.lower().strip())
        s2=normalizeString(s2.lower().strip())
        initpairs.append([s1,s2])
#         print("S1 : ",s1)
#         print("S2: ",s2)
    #print(len(initpairs))
    return initpairs

#filter pairs
max_length = 10
def filterPairs(initpairs):
    #filtering conditions in addition to max_length
    eng_prefixes = (
        "i am ", "i m ",
        "he is", "he s ",
        "she is", "she s ",
        "you are", "you re ",
        "we are", "we re ",
        "they are", "they re "
    )

    pairs=[]
    for pair in initpairs:
        if len(pair[0].split(" ")) < max_length and len(pair[1].split(" ")) < max_length and pair[0].lower().startswith(eng_prefixes):
            pairs.append(pair)

    print("Number of pairs after filtering:", len(pairs))
    return pairs #list of lists

# %%
class Vocab:
    def __init__(self, name):
        self.name=name
        self.word2index={'SOS':0, 'EOS':1}
        self.index2word={0:'SOS', 1:'EOS'}
        self.word2count={}
        self.nwords=2
    
    def buildVocab(self,s):
        for word in s.split(" "):
            if word not in self.word2index:
                self.word2index[word]=self.nwords
                self.index2word[self.nwords]=word
                self.word2count[word]=1
                self.nwords+=1
            else:
                self.word2count[word]+=1

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, embed_size, hidden_size, dropout_p=0.1):
        super().__init__()
        self.embedding = nn.Embedding(input_size, embed_size)
        self.dropout = nn.Dropout(dropout_p)
        self.lstm = nn.LSTM(embed_size, hidden_size, batch_first=True)  # Use LSTM instead of GRU
    
    def forward(self, x):
        x = self.embedding(x)
        x = self.dropout(x)
        outputs, (hidden, cell) = self.lstm(x)  # LSTM returns hidden state and cell state
        return outputs, (hidden, cell)

# %%
import torch
import torch.nn as nn

class Decoder(nn.Module):
    def __init__(self, output_size, embed_size, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(output_size, embed_size)
        self.relu = nn.ReLU()
        self.lstm = nn.LSTM(embed_size, hidden_size, batch_first=True)  # Use LSTM instead of GRU
        self.linear = nn.Linear(hidden_size, output_size)
        self.log_softmax = nn.LogSoftmax(dim=-1)
    
    def forward(self, x, prev_hidden):
        x = self.embedding(x)
        x = self.relu(x)
        output, (hidden, cell) = self.lstm(x, prev_hidden)  # LSTM returns hidden state and cell state
        y = self.linear(output)
        y = self.log_softmax(y)
        return y, (hidden, cell)

# %%
def get_input_ids(sentence,langobj):
    input_ids=[]
    for word in sentence.split(" "):
        input_ids.append(langobj.word2index[word])
    
    if langobj.name=='fre': #translation-direction sensitive
        input_ids.append(langobj.word2index['EOS'])
    else:
        input_ids.insert(0,langobj.word2index['SOS'])
        input_ids.append(langobj.word2index['EOS'])
    return torch.tensor(input_ids)

# %%
class CustomDataset(Dataset):
    def __init__(self):
        super().__init__()
    
    def __len__(self):
        return length
    
    def __getitem__(self,idx):
        t=pairs[idx][0] #translation-direction sensitive --> english is first ind
        s=pairs[idx][1] #translation-direction sensitive
        s_input_ids=torch.zeros(max_length+1, dtype=torch.int64)
        t_input_ids=torch.zeros(max_length+2, dtype=torch.int64)
        s_input_ids[:len(s.split(" "))+1]=get_input_ids(s,fre) #translation-direction sensitive
        t_input_ids[:len(t.split(" "))+2]=get_input_ids(t,eng) #translation-direction sensitive
        
        return s_input_ids, t_input_ids

# %%
def train_one_epoch():
    encoder.train()
    decoder.train()
    track_loss=0
    
    for i, (s_ids,t_ids) in enumerate(train_dataloader):
        s_ids=s_ids.to(device)
        t_ids=t_ids.to(device)
        encoder_outputs, encoder_hidden=encoder(s_ids)
        decoder_hidden=encoder_hidden
        yhats, decoder_hidden = decoder(t_ids[:,0:-1],decoder_hidden)
                    
        gt=t_ids[:,1:]
        
        yhats_reshaped=yhats.view(-1,yhats.shape[-1])
        
        gt=gt.reshape(-1)
        
        
        loss=loss_fn(yhats_reshaped,gt)
        track_loss+=loss.item()
        
        opte.zero_grad()
        optd.zero_grad()
        
        loss.backward()
        
        opte.step()
        optd.step()
        
    return track_loss/len(train_dataloader)

# %%
def ids2Sentence(ids,vocab):
    sentence=""
    for id in ids.squeeze():
        if id==0:
            continue
        word=vocab.index2word[id.item()]
        sentence+=word + " "
        if id==1:
            break
    return sentence

# %%
#eval loop (written assuming batch_size=1)
def eval_one_epoch():
    encoder.eval()
    decoder.eval()
    track_loss=0
    with torch.no_grad():
        for i, (s_ids,t_ids) in enumerate(test_dataloader):
            s_ids=s_ids.to(device)
            t_ids=t_ids.to(device)
            encoder_outputs, encoder_hidden=encoder(s_ids)
            decoder_hidden=encoder_hidden #n_dim=3
            input_ids=t_ids[:,0]
            yhats=[]
            pred_sentence=""
            for j in range(1,max_length+1): #j starts from 1
                probs, decoder_hidden = decoder(input_ids.unsqueeze(1),decoder_hidden)
                yhats.append(probs)
                _,input_ids=torch.topk(probs,1,dim=-1)
                input_ids=input_ids.squeeze(1,2) #still a tensor
                word=eng.index2word[input_ids.item()] #batch_size=1
                pred_sentence+=word + " "
                if input_ids.item() == 1: #batch_size=1
                    break
                                
            src_sentence=ids2Sentence(s_ids,fre) #translation-direction sensitive
            gt_sentence=ids2Sentence(t_ids,eng) #translation-direction sensitive
            
            print("-----------------------------------")
            print("Source Sentence:",src_sentence)
            print("GT Sentence:",gt_sentence)
            print("Predicted Sentence:",pred_sentence)
            
            yhats_cat=torch.cat(yhats,dim=1)
            yhats_reshaped=yhats_cat.view(-1,yhats_cat.shape[-1])
            gt=t_ids[:,1:j+1]
            gt=gt.view(-1)
#             gt --> ground truth
            

            loss=loss_fn(yhats_reshaped,gt)
            track_loss+=loss.item()
            
            
        print("-----------------------------------")
        return track_loss/len(test_dataloader)

# %%
#read data
data=open("/kaggle/input/eng-fra/eng-fra.txt").read().strip().split('\n')
print("Total number of pairs:",len(data))

#create pairs (create + normalize)
initpairs=createNormalizedPairs() #list of lists. Each inner list is a pair

# Task 1
print("S1 and S2")
print(initpairs[300])


#filter pairs
pairs=filterPairs(initpairs)
length=len(pairs)
print(pairs[300])

#create Vocab objects for each language
eng=Vocab('eng')
fre=Vocab('fre')

#build the vocab
for pair in pairs:
    eng.buildVocab(pair[0])
    fre.buildVocab(pair[1])

#print vocab size
print("English Vocab Length:",eng.nwords)
print("French Vocab Length:",fre.nwords)    
    
dataset=CustomDataset()
train_dataset,test_dataset=random_split(dataset,[0.99,0.01])

print(train_dataset[300])

batch_size=32
train_dataloader=DataLoader(dataset=train_dataset,batch_size=batch_size, shuffle=False)
test_dataloader=DataLoader(dataset=test_dataset,batch_size=1, shuffle=False)

    
embed_size=100
hidden_size=128

encoder=Encoder(fre.nwords,embed_size,hidden_size).to(device) #translation-direction sensitive
decoder=Decoder(eng.nwords,embed_size,hidden_size).to(device) #translation-direction sensitive

loss_fn=nn.NLLLoss().to(device)
lr=0.001
opte=optim.Adam(params=encoder.parameters(), lr=lr)
optd=optim.Adam(params=decoder.parameters(), lr=lr)

n_epochs=100

for e in range(n_epochs):
    print("Epoch=",e+1, " Loss=", train_one_epoch(), sep="")

for e in range(1):
    print("Epoch=",e+1, " Loss=", eval_one_epoch(), sep="")
# Out:
# Total number of pairs: 135842
# S1 and S2
# ['i m ugly', 'je suis laid']
# Number of pairs after filtering: 11445
# ['i m all set', 'je suis tout a fait prete']
# English Vocab Length: 2991
# French Vocab Length: 4601
# (tensor([   2,  296,    7,  245,  289, 1149,  498,   10, 3953,    1,    0]), tensor([   0,    2,    3,  146,   43,  157, 2465,  290,    1,    0,    0,    0]))
# Epoch=1 Loss=2.552940502636869
# Epoch=2 Loss=1.7787637223660107
# Epoch=3 Loss=1.5518498612121796
# Epoch=4 Loss=1.3953741412767222
# Epoch=5 Loss=1.2754920759671171
# Epoch=6 Loss=1.1752160000129486
# Epoch=7 Loss=1.0883595975352005
# Epoch=8 Loss=1.0100452740427475
# Epoch=9 Loss=0.9394859766456443
# Epoch=10 Loss=0.8762586755651823
# Epoch=11 Loss=0.8176159575791426
# Epoch=12 Loss=0.7607350636535967
# Epoch=13 Loss=0.7101277927277794
# Epoch=14 Loss=0.6606718645968908
# Epoch=15 Loss=0.6164507577956563
# Epoch=16 Loss=0.574978108011501
# Epoch=17 Loss=0.537022390499921
# Epoch=18 Loss=0.5003775261657338
# Epoch=19 Loss=0.4677928564833923
# Epoch=20 Loss=0.4370496804445562
# Epoch=21 Loss=0.4079276488700383
# Epoch=22 Loss=0.3800876743356946
# Epoch=23 Loss=0.354734212181098
# Epoch=24 Loss=0.3306096604802239
# Epoch=25 Loss=0.30841104408175174
# Epoch=26 Loss=0.28907675375820885
# Epoch=27 Loss=0.2691680949653538
# Epoch=28 Loss=0.25008741853312705
# Epoch=29 Loss=0.23442556511768153
# Epoch=30 Loss=0.2185889228548802
# Epoch=31 Loss=0.20571796137472273
# Epoch=32 Loss=0.19180666779653288
# Epoch=33 Loss=0.1794669983305142
# Epoch=34 Loss=0.16867015907462213
# Epoch=35 Loss=0.15936510807401696
# Epoch=36 Loss=0.14787760190141033
# Epoch=37 Loss=0.13952912639983941
# Epoch=38 Loss=0.13133313060593857
# Epoch=39 Loss=0.12150879661277146
# Epoch=40 Loss=0.11460556569968311
# Epoch=41 Loss=0.10855180206118335
# Epoch=42 Loss=0.10159821380979159
# Epoch=43 Loss=0.09635994779339559
# Epoch=44 Loss=0.0906690058363995
# Epoch=45 Loss=0.0857049485248789
# Epoch=46 Loss=0.08034553151367836
# Epoch=47 Loss=0.07639909631139795
# Epoch=48 Loss=0.07283878277095271
# Epoch=49 Loss=0.06884502169846649
# Epoch=50 Loss=0.06600320949547098
# Epoch=51 Loss=0.06241927462774263
# Epoch=52 Loss=0.05992004949153519
# Epoch=53 Loss=0.057634107952832546
# Epoch=54 Loss=0.0541882001755523
# Epoch=55 Loss=0.05231525634258041
# Epoch=56 Loss=0.05043798702322996
# Epoch=57 Loss=0.04856965989399124
# Epoch=58 Loss=0.046579388489054754
# Epoch=59 Loss=0.04506910908704912
# Epoch=60 Loss=0.04271246996498339
# Epoch=61 Loss=0.04200719582887603
# Epoch=62 Loss=0.04031930084432095
# Epoch=63 Loss=0.038824906685507636
# Epoch=64 Loss=0.03735599771476495
# Epoch=65 Loss=0.03732135384146806
# Epoch=66 Loss=0.03572172448039055
# Epoch=67 Loss=0.03494285703013638
# Epoch=68 Loss=0.03358277452381616
# Epoch=69 Loss=0.03273608747436862
# Epoch=70 Loss=0.03248860437790273
# Epoch=71 Loss=0.031474257973809795
# Epoch=72 Loss=0.03040810971861889
# Epoch=73 Loss=0.029760396386116324
# Epoch=74 Loss=0.029691386379754093
# Epoch=75 Loss=0.028290211589364202
# Epoch=76 Loss=0.02767918799170883
# Epoch=77 Loss=0.027127987701891804
# Epoch=78 Loss=0.02712550414135863
# Epoch=79 Loss=0.02663290846148427
# Epoch=80 Loss=0.026968453213585618
# Epoch=81 Loss=0.025961613838895368
# Epoch=82 Loss=0.025923004642319145
# Epoch=83 Loss=0.02452503271092674
# Epoch=84 Loss=0.02369198199807548
# Epoch=85 Loss=0.023822478274486854
# Epoch=86 Loss=0.023617358671658685
# Epoch=87 Loss=0.023930012679685066
# Epoch=88 Loss=0.024740503141394175
# Epoch=89 Loss=0.022771552648447768
# Epoch=90 Loss=0.02317188013095776
# Epoch=91 Loss=0.02218652236337682
# Epoch=92 Loss=0.022522510403216307
# Epoch=93 Loss=0.022060685538240827
# Epoch=94 Loss=0.02219043375602858
# Epoch=95 Loss=0.021484244737157623
# Epoch=96 Loss=0.021823240560643428
# Epoch=97 Loss=0.02188883639944219
# Epoch=98 Loss=0.02149894562333455
# Epoch=99 Loss=0.021345587251839084
# Epoch=100 Loss=0.020656795978782252
# -----------------------------------
# Source Sentence: nous nous aimons EOS
# GT Sentence: we re in love EOS
# Predicted Sentence: we re tempting fate EOS
# -----------------------------------
# Source Sentence: il ecrit une longue lettre EOS
# GT Sentence: he s writing a long letter EOS
# Predicted Sentence: he s writing a letter EOS
# -----------------------------------
# Source Sentence: je ne suis pas laide EOS
# GT Sentence: i m not ugly EOS
# Predicted Sentence: i m not ugly EOS
# -----------------------------------
# Source Sentence: tu es fou EOS
# GT Sentence: you are crazy EOS
# Predicted Sentence: you re demented EOS
# -----------------------------------
# Source Sentence: je travaille chez mcdonald s EOS
# GT Sentence: i m working for mcdonald s EOS
# Predicted Sentence: i am bored to her EOS
# -----------------------------------
# Source Sentence: il est force de remarquer votre erreur EOS
# GT Sentence: he s bound to notice your mistake EOS
# Predicted Sentence: he is tall and so by girls EOS
# -----------------------------------
# Source Sentence: je suis terriblement fatigue EOS
# GT Sentence: i m awfully tired EOS
# Predicted Sentence: i m awfully tired of reading EOS
# -----------------------------------
# Source Sentence: elles sont toutes les deux amoureuses du meme type EOS
# GT Sentence: they re both in love with the same guy EOS
# Predicted Sentence: they re both in love with the same guy EOS
# -----------------------------------
# Source Sentence: ils ne sont pas si mauvais EOS
# GT Sentence: they re not so bad EOS
# Predicted Sentence: they re not so cute EOS
# -----------------------------------
# Source Sentence: vous n etes pas aussi maligne que moi EOS
# GT Sentence: you re not as smart as me EOS
# Predicted Sentence: you re not as smart as me EOS
# -----------------------------------
# Source Sentence: je ne suis plus en colere apres vous EOS
# GT Sentence: i m no longer angry at you EOS
# Predicted Sentence: i m no longer angry at you EOS
# -----------------------------------
# Source Sentence: c est un vieux de la vieille EOS
# GT Sentence: he s an old timer EOS
# Predicted Sentence: he s the old age EOS
# -----------------------------------
# Source Sentence: je ne suis pas ton petit ami EOS
# GT Sentence: i m not your boyfriend EOS
# Predicted Sentence: i m not your friend EOS
# -----------------------------------
# Source Sentence: elle porte des talons hauts EOS
# GT Sentence: she s wearing high heels EOS
# Predicted Sentence: she s wearing a hat EOS
# -----------------------------------
# Source Sentence: tu as trois ans de moins que tom EOS
# GT Sentence: you re three years younger than tom EOS
# Predicted Sentence: you re three hours touch after our i am EOS
# -----------------------------------
# Source Sentence: elles n ont pas toujours raison EOS
# GT Sentence: they re not always right EOS
# Predicted Sentence: they re not always right EOS
# -----------------------------------
# Source Sentence: je ne fais pas erreur EOS
# GT Sentence: i m not mistaken EOS
# Predicted Sentence: i m not sleeping EOS
# -----------------------------------
# Source Sentence: vous etes plantee EOS
# GT Sentence: you re stuck EOS
# Predicted Sentence: you re stuck EOS
# -----------------------------------
# Source Sentence: je suis completement embrouille EOS
# GT Sentence: i m totally confused EOS
# Predicted Sentence: i m totally confused EOS
# -----------------------------------
# Source Sentence: nous ne sommes pas du coin EOS
# GT Sentence: we re not from around here EOS
# Predicted Sentence: we re not from around here EOS
# -----------------------------------
# Source Sentence: il a peur de danser EOS
# GT Sentence: he s afraid to dance EOS
# Predicted Sentence: he is afraid to be late EOS
# -----------------------------------
# Source Sentence: elle ne fait pas le poids avec moi EOS
# GT Sentence: she is no match for me EOS
# Predicted Sentence: she s not done with me at all EOS
# -----------------------------------
# Source Sentence: il se planque EOS
# GT Sentence: he s gone into hiding EOS
# Predicted Sentence: he s out of practice EOS
# -----------------------------------
# Source Sentence: vous n etes pas aussi petits que moi EOS
# GT Sentence: you aren t as short as i am EOS
# Predicted Sentence: you re not as smart as me EOS
# -----------------------------------
# Source Sentence: c est un homme jaloux EOS
# GT Sentence: he is a jealous man EOS
# Predicted Sentence: he is a man who loves ceremonies EOS
# -----------------------------------
# Source Sentence: je me rejouis d entendre votre voix EOS
# GT Sentence: i am happy to hear your voice EOS
# Predicted Sentence: i m glad to hear that early EOS
# -----------------------------------
# Source Sentence: tu es tres contrariee EOS
# GT Sentence: you re very upset EOS
# Predicted Sentence: you re very upset EOS
# -----------------------------------
# Source Sentence: je suis desole si je vous ai effraye EOS
# GT Sentence: i m sorry if i frightened you EOS
# Predicted Sentence: i m sorry if i frightened you EOS
# -----------------------------------
# Source Sentence: il ne fait que se plaindre EOS
# GT Sentence: he is constantly complaining EOS
# Predicted Sentence: he s out of waiting EOS
# -----------------------------------
# Source Sentence: elle est fiere de ses enfants EOS
# GT Sentence: she is proud of her children EOS
# Predicted Sentence: she s open to her EOS
# -----------------------------------
# Source Sentence: je suis ruine EOS
# GT Sentence: i m ruined EOS
# Predicted Sentence: i m broke EOS
# -----------------------------------
# Source Sentence: j essaye d apprendre l anglais EOS
# GT Sentence: i am trying to learn english EOS
# Predicted Sentence: i m trying to save him short of situation EOS
# -----------------------------------
# Source Sentence: je vais dormir EOS
# GT Sentence: i am going to sleep EOS
# Predicted Sentence: i am going to bed EOS
# -----------------------------------
# Source Sentence: elle lui est apparentee de maniere lointaine EOS
# GT Sentence: she is distantly related to him EOS
# Predicted Sentence: she is related to him by marriage EOS
# -----------------------------------
# Source Sentence: ils parlent EOS
# GT Sentence: they re talking EOS
# Predicted Sentence: they re talking EOS
# -----------------------------------
# Source Sentence: j essaie de me rappeler EOS
# GT Sentence: i m trying to remember EOS
# Predicted Sentence: i m trying to talk to you EOS
# -----------------------------------
# Source Sentence: ils courent maintenant EOS
# GT Sentence: they are running now EOS
# Predicted Sentence: they are reading here EOS
# -----------------------------------
# Source Sentence: elles le font comme il faut EOS
# GT Sentence: they re doing it right EOS
# Predicted Sentence: they re doing it right EOS
# -----------------------------------
# Source Sentence: je ne suis pas libre tout de suite EOS
# GT Sentence: i m not available right now EOS
# Predicted Sentence: i m not like you are EOS
# -----------------------------------
# Source Sentence: elle est davantage mignonne que belle EOS
# GT Sentence: she is more pretty than beautiful EOS
# Predicted Sentence: she is as poor as i am EOS
# -----------------------------------
# Source Sentence: j apprends tant de toi EOS
# GT Sentence: i m learning so much from you EOS
# Predicted Sentence: i m learning so much from you EOS
# -----------------------------------
# Source Sentence: je suis etudiant a l universite de hyogo EOS
# GT Sentence: i am a student at hyogo university EOS
# Predicted Sentence: i m a university student EOS
# -----------------------------------
# Source Sentence: je suis heureux que vous veniez EOS
# GT Sentence: i m glad you re coming EOS
# Predicted Sentence: i m glad that you ll come EOS
# -----------------------------------
# Source Sentence: je ne suis pas malheureuse EOS
# GT Sentence: i m not miserable EOS
# Predicted Sentence: i m not unhappy EOS
# -----------------------------------
# Source Sentence: tu es toujours celibataire pas vrai ? EOS
# GT Sentence: you re still single aren t you ? EOS
# Predicted Sentence: you re still single aren t you ? EOS
# -----------------------------------
# Source Sentence: nous ne sommes pas seules EOS
# GT Sentence: we re not alone EOS
# Predicted Sentence: we are not alone EOS
# -----------------------------------
# Source Sentence: nous ne sommes pas vraiment freres EOS
# GT Sentence: we re not really brothers EOS
# Predicted Sentence: we re not really sure EOS
# -----------------------------------
# Source Sentence: je ne suis pas vegetarienne EOS
# GT Sentence: i m not a vegetarian EOS
# Predicted Sentence: i m not a professional EOS
# -----------------------------------
# Source Sentence: je suis presse aujourd hui EOS
# GT Sentence: i m in a hurry today EOS
# Predicted Sentence: i am in charge of my good EOS
# -----------------------------------
# Source Sentence: je suis desole je ne t ai pas reconnu EOS
# GT Sentence: i m sorry i didn t recognize you EOS
# Predicted Sentence: i m sorry i didn t recognize you EOS
# -----------------------------------
# Source Sentence: je prends du poids EOS
# GT Sentence: i m gaining weight EOS
# Predicted Sentence: i m taking a diet EOS
# -----------------------------------
# Source Sentence: il est lyceen EOS
# GT Sentence: he s a high school student EOS
# Predicted Sentence: he is a student at a university EOS
# -----------------------------------
# Source Sentence: je n ai pas sommeil EOS
# GT Sentence: i m not sleepy EOS
# Predicted Sentence: i m not sleepy EOS
# -----------------------------------
# Source Sentence: il a honte de son echec EOS
# GT Sentence: he is ashamed of his failure EOS
# Predicted Sentence: he is ashamed of his success EOS
# -----------------------------------
# Source Sentence: elles viennent nous chercher EOS
# GT Sentence: they re coming for us EOS
# Predicted Sentence: they re coming for us EOS
# -----------------------------------
# Source Sentence: vous etes talentueuses EOS
# GT Sentence: you re talented EOS
# Predicted Sentence: you re talented EOS
# -----------------------------------
# Source Sentence: il est parfait en tout EOS
# GT Sentence: he s perfect at everything EOS
# Predicted Sentence: he s just it EOS
# -----------------------------------
# Source Sentence: nous sommes dans le petrin EOS
# GT Sentence: we re in trouble EOS
# Predicted Sentence: we re up a creek without a paddle EOS
# -----------------------------------
# Source Sentence: je la rends EOS
# GT Sentence: i m giving it back EOS
# Predicted Sentence: i m making tea EOS
# -----------------------------------
# Source Sentence: il est en train de laver la voiture EOS
# GT Sentence: he is washing the car EOS
# Predicted Sentence: he s doing my age EOS
# -----------------------------------
# Source Sentence: je suis trop vieux pour ca EOS
# GT Sentence: i m too old for this EOS
# Predicted Sentence: i m too old for this EOS
# -----------------------------------
# Source Sentence: vous etes plein de surprises EOS
# GT Sentence: you re full of surprises EOS
# Predicted Sentence: you re full of surprises EOS
# -----------------------------------
# Source Sentence: vous etes consciencieux EOS
# GT Sentence: you re conscientious EOS
# Predicted Sentence: you re conscientious EOS
# -----------------------------------
# Source Sentence: on nous encourage a utiliser notre imagination EOS
# GT Sentence: we are encouraged to use our imagination EOS
# Predicted Sentence: we re just looking for each other people EOS
# -----------------------------------
# Source Sentence: ils ne sont pas tous occupes EOS
# GT Sentence: they re not all busy EOS
# Predicted Sentence: they re not all busy EOS
# -----------------------------------
# Source Sentence: vous etes extravertis EOS
# GT Sentence: you re extroverted EOS
# Predicted Sentence: you re being silly EOS
# -----------------------------------
# Source Sentence: c est un etudiant de deuxieme annee EOS
# GT Sentence: he s a sophomore EOS
# Predicted Sentence: he is a student who studies very hard EOS
# -----------------------------------
# Source Sentence: elles sont toujours ensemble EOS
# GT Sentence: they re still together EOS
# Predicted Sentence: they re still together EOS
# -----------------------------------
# Source Sentence: c est mon ami le connaissez vous ? EOS
# GT Sentence: he s my friend do you know him ? EOS
# Predicted Sentence: he s my friend do you know him ? EOS
# -----------------------------------
# Source Sentence: c est un voleur EOS
# GT Sentence: he is a thief EOS
# Predicted Sentence: he is a student EOS
# -----------------------------------
# Source Sentence: je suis completement saoul EOS
# GT Sentence: i m totally drunk EOS
# Predicted Sentence: i m completely drunk EOS
# -----------------------------------
# Source Sentence: vous etes impressionnees n est ce pas ? EOS
# GT Sentence: you re impressed aren t you ? EOS
# Predicted Sentence: you re impressed aren t you ? EOS
# -----------------------------------
# Source Sentence: il se plaint tout le temps EOS
# GT Sentence: he is always complaining EOS
# Predicted Sentence: he s always complaining EOS
# -----------------------------------
# Source Sentence: il est soul EOS
# GT Sentence: he s drunk EOS
# Predicted Sentence: he is drunk EOS
# -----------------------------------
# Source Sentence: il est tellement adorable ! EOS
# GT Sentence: he s such a sweetheart EOS
# Predicted Sentence: he s such an idiot ! EOS
# -----------------------------------
# Source Sentence: je refuse de te vendre ma voiture EOS
# GT Sentence: i m not selling you my car EOS
# Predicted Sentence: i m not selling you my car EOS
# -----------------------------------
# Source Sentence: rien ne me soucie EOS
# GT Sentence: i m not worried about anything EOS
# Predicted Sentence: i m not blushing with me EOS
# -----------------------------------
# Source Sentence: vous etes tres effrontes EOS
# GT Sentence: you re very forward EOS
# Predicted Sentence: you re very forward EOS
# -----------------------------------
# Source Sentence: je suis sur qu elles vont gagner EOS
# GT Sentence: i m sure they ll win EOS
# Predicted Sentence: i m sure they ll win EOS
# -----------------------------------
# Source Sentence: je suis optimiste EOS
# GT Sentence: i m optimistic EOS
# Predicted Sentence: i am an italian EOS
# -----------------------------------
# Source Sentence: je me trouve juste derriere toi EOS
# GT Sentence: i m right behind you EOS
# Predicted Sentence: i m right behind you EOS
# -----------------------------------
# Source Sentence: nous sommes forts EOS
# GT Sentence: we re strong EOS
# Predicted Sentence: we re rich EOS
# -----------------------------------
# Source Sentence: il est toujours chez lui le lundi EOS
# GT Sentence: he is always at home on mondays EOS
# Predicted Sentence: he s always at home on mondays EOS
# -----------------------------------
# Source Sentence: elles ne sont pas seules EOS
# GT Sentence: they re not alone EOS
# Predicted Sentence: they aren t alone EOS
# -----------------------------------
# Source Sentence: c est un poete EOS
# GT Sentence: he is a poet EOS
# Predicted Sentence: he is a student EOS
# -----------------------------------
# Source Sentence: je ne suis pas amere EOS
# GT Sentence: i m not bitter EOS
# Predicted Sentence: i m not tall EOS
# -----------------------------------
# Source Sentence: je ne vais vous le montrer qu une fois EOS
# GT Sentence: i m only going to show you once EOS
# Predicted Sentence: i m only going to show you once EOS
# -----------------------------------
# Source Sentence: je suis ivre EOS
# GT Sentence: i m drunk EOS
# Predicted Sentence: i m drunk EOS
# -----------------------------------
# Source Sentence: nous ne sommes pas toutes enseignantes EOS
# GT Sentence: we re not all teachers EOS
# Predicted Sentence: we re not all teachers EOS
# -----------------------------------
# Source Sentence: il est toujours a court de liquide EOS
# GT Sentence: he s always running short of cash EOS
# Predicted Sentence: he is always reading comics EOS
# -----------------------------------
# Source Sentence: je fais la diete EOS
# GT Sentence: i m fasting EOS
# Predicted Sentence: i m fasting EOS
# -----------------------------------
# Source Sentence: je suis dispose a me repentir EOS
# GT Sentence: i m ready to make amends EOS
# Predicted Sentence: i m delighted to the police EOS
# -----------------------------------
# Source Sentence: vous etes tres indelicat EOS
# GT Sentence: you are very insensitive EOS
# Predicted Sentence: you are very insensitive EOS
# -----------------------------------
# Source Sentence: vous etes creatives EOS
# GT Sentence: you re creative EOS
# Predicted Sentence: you are big EOS
# -----------------------------------
# Source Sentence: tu es vraiment embetant EOS
# GT Sentence: you re really annoying EOS
# Predicted Sentence: you re really annoying EOS
# -----------------------------------
# Source Sentence: c est le plus grand de tous les garcons EOS
# GT Sentence: he is the tallest of all boys EOS
# Predicted Sentence: he is the tallest person have a cultured EOS
# -----------------------------------
# Source Sentence: nous partons ce soir EOS
# GT Sentence: we re leaving tonight EOS
# Predicted Sentence: we re leaving the way EOS
# -----------------------------------
# Source Sentence: je viens de tokyo japon EOS
# GT Sentence: i m from tokyo japan EOS
# Predicted Sentence: i am from tokyo tomorrow EOS
# -----------------------------------
# Source Sentence: je suis en retard n est ce pas ? EOS
# GT Sentence: i m late aren t i ? EOS
# Predicted Sentence: i m fit aren t you ? EOS
# -----------------------------------
# Source Sentence: elle a l habitude de faire la cuisine EOS
# GT Sentence: she is used to cooking EOS
# Predicted Sentence: she is used to the president EOS
# -----------------------------------
# Source Sentence: je suis une vraie loque EOS
# GT Sentence: i m a total wreck EOS
# Predicted Sentence: i m a social worker EOS
# -----------------------------------
# Source Sentence: je suis fort impressionnee EOS
# GT Sentence: i m very impressed EOS
# Predicted Sentence: i m definitely impressed EOS
# -----------------------------------
# Source Sentence: il n est pas encore la EOS
# GT Sentence: he s not in yet EOS
# Predicted Sentence: he s not here yet EOS
# -----------------------------------
# Source Sentence: il peut enseigner le francais et l anglais EOS
# GT Sentence: he is capable of teaching both english and french EOS
# Predicted Sentence: he is with the problem of the class EOS
# -----------------------------------
# Source Sentence: on dit qu il est riche EOS
# GT Sentence: he is said to be rich EOS
# Predicted Sentence: he is being rich as rich as a bat EOS
# -----------------------------------
# Source Sentence: je suis un electricien EOS
# GT Sentence: i am an electrician EOS
# Predicted Sentence: i am an electrician EOS
# -----------------------------------
# Source Sentence: elle porte un chapeau sympa EOS
# GT Sentence: she s wearing a cool hat EOS
# Predicted Sentence: she s wearing a great really ugly EOS
# -----------------------------------
# Source Sentence: nous sommes les meilleurs amis EOS
# GT Sentence: we re best friends EOS
# Predicted Sentence: we re the best student EOS
# -----------------------------------
# Source Sentence: je suis desole je ne vous ai pas reconnus EOS
# GT Sentence: i m sorry i didn t recognize you EOS
# Predicted Sentence: i m sorry i didn t recognize you EOS
# -----------------------------------
# Source Sentence: je n ai pas tres faim a l instant EOS
# GT Sentence: i m not feeling very hungry right now EOS
# Predicted Sentence: i m not very well keep him EOS
# -----------------------------------
# Source Sentence: je ne suis pas tres bon en francais EOS
# GT Sentence: i m not very good at french EOS
# Predicted Sentence: i m not very good at french EOS
# -----------------------------------
# Source Sentence: j en suis contente EOS
# GT Sentence: i m happy with that EOS
# Predicted Sentence: i m happy with that EOS
# -----------------------------------
# Source Sentence: je ne suis pas si saoule EOS
# GT Sentence: i m not that drunk EOS
# Predicted Sentence: i m not that worried EOS
# -----------------------------------
# Source Sentence: nous en sommes pour ainsi dire certaines EOS
# GT Sentence: we re quite certain of that EOS
# Predicted Sentence: we re quite certain of that EOS
# -----------------------------------
# Epoch=1 Loss=3.911329447119211
